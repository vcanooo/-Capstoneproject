# %%
import pandas as pd
df = pd.read_csv('Chicago_Public_Schools_-_School_Progress_Reports_SY2223.csv')
df.head(651)
# Out:
#      School_ID            Short_Name  \
# 0       610125                  RUIZ
# 1       609728          ROOSEVELT HS
# 2       610040                 LLOYD
# 3       609983                HEDGES
# 4       610534         SKINNER NORTH
# ..         ...                   ...
# 646     610563  BACK OF THE YARDS HS
# 647     610570  OMBUDSMAN - SOUTH HS
# 648     609764             JUAREZ HS
# 649     610106               PICCOLO
# 650     609726             BROOKS HS
#
#                                            Long_Name           School_Type  \
# 0                      Irma C Ruiz Elementary School          Neighborhood
# 1                     Theodore Roosevelt High School          Neighborhood
# 2                    Henry D Lloyd Elementary School          Neighborhood
# 3                     James Hedges Elementary School          Neighborhood
# 4                                      Skinner North             Classical
# ...

# %%
# 1. Remove irrelevant columns that don't contribute to the analysis
# For example, we may remove columns like 'Address', 'Phone Number', etc.
columns_to_drop = ['Address', 'Phone Number', 'City', 'State']  # Add the column names to drop

# %%
# We need to remove specific categories that are irrelevant to our question. For example we are getting rid 
# middle schools and elemantary schools. Our focus is Highschool. 
print(df)
category_to_remove ='ES'
categort_to_remove ='MS'
# Out:
#      School_ID            Short_Name  \
# 0       610125                  RUIZ
# 1       609728          ROOSEVELT HS
# 2       610040                 LLOYD
# 3       609983                HEDGES
# 4       610534         SKINNER NORTH
# ..         ...                   ...
# 646     610563  BACK OF THE YARDS HS
# 647     610570  OMBUDSMAN - SOUTH HS
# 648     609764             JUAREZ HS
# 649     610106               PICCOLO
# 650     609726             BROOKS HS
#
#                                            Long_Name           School_Type  \
# 0                      Irma C Ruiz Elementary School          Neighborhood
# 1                     Theodore Roosevelt High School          Neighborhood
# 2                    Henry D Lloyd Elementary School          Neighborhood
# 3                     James Hedges Elementary School          Neighborhood
# 4                                      Skinner North             Classical
# ...

# %%
print(df)

# Create a pivot table to see the mean score for each category and school type
pivot_table = df.pivot_table(index='Category', columns='SchoolType', values='ScoreColumn')
# Out:
#      School_ID            Short_Name  \
# 0       610125                  RUIZ
# 1       609728          ROOSEVELT HS
# 2       610040                 LLOYD
# 3       609983                HEDGES
# 4       610534         SKINNER NORTH
# ..         ...                   ...
# 646     610563  BACK OF THE YARDS HS
# 647     610570  OMBUDSMAN - SOUTH HS
# 648     609764             JUAREZ HS
# 649     610106               PICCOLO
# 650     609726             BROOKS HS
#
#                                            Long_Name           School_Type  \
# 0                      Irma C Ruiz Elementary School          Neighborhood
# 1                     Theodore Roosevelt High School          Neighborhood
# 2                    Henry D Lloyd Elementary School          Neighborhood
# 3                     James Hedges Elementary School          Neighborhood
# 4                                      Skinner North             Classical
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('Chicago_Public_Schools_-_School_Progress_Reports_SY2223.csv')

# Create a bar plot to visualize the count of unique 'Zip' values in the DataFrame
df['Zip'].value_counts().plot(kind='bar')
plt.xlabel('Zip')
plt.ylabel('Count')
plt.title('CPS - Count of Unique Zip Values')
plt.show()
